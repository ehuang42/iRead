# %%
pip install beautifulsoup4
# Out:
# ...
# You are using pip version 18.1, however version 19.1.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install requests
# Out:
# ...
# You are using pip version 18.1, however version 19.1.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install Pandas
# Out:
# ...
# You are using pip version 18.1, however version 19.1.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install lxml
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from bs4 import BeautifulSoup as soup
import requests
# grabbing the page

def getHTML(url_list):
    res = requests.get(url, timeout=30)
    return (soup(res.text,'lxml'))

def grab(parsed_soup, header, className,): 
    soup = parsed_soup.findAll(header, {"class": className})
    return(soup)

# %%
url_list = ['https://www.matataiwan.com/category/mata-%e9%81%b8%e6%9b%b8/', 'https://www.matataiwan.com/category/mata-%e9%81%b8%e6%9b%b8/page/2/']
for i in range(96):
    if i ==0:
        url_list.append('https://www.matataiwan.com/tag/culture/')
    else:
        url_list.append('https://www.matataiwan.com/tag/culture/page/' + str(i+1) + '/')
links_list = []
for url in url_list:
    print('log', url)
    read_html = getHTML(url)
    links_list.append(grab(read_html, 'div', 'grid-header-box'))
# Out:
# log https://www.matataiwan.com/category/mata-%e9%81%b8%e6%9b%b8/
# log https://www.matataiwan.com/category/mata-%e9%81%b8%e6%9b%b8/page/2/
# log https://www.matataiwan.com/tag/culture/
# log https://www.matataiwan.com/tag/culture/page/2/
# log https://www.matataiwan.com/tag/culture/page/3/
# log https://www.matataiwan.com/tag/culture/page/4/
# log https://www.matataiwan.com/tag/culture/page/5/
# log https://www.matataiwan.com/tag/culture/page/6/
# log https://www.matataiwan.com/tag/culture/page/7/
# log https://www.matataiwan.com/tag/culture/page/8/
# log https://www.matataiwan.com/tag/culture/page/9/
# log https://www.matataiwan.com/tag/culture/page/10/
# log https://www.matataiwan.com/tag/culture/page/11/
# log https://www.matataiwan.com/tag/culture/page/12/
# log https://www.matataiwan.com/tag/culture/page/13/
# log https://www.matataiwan.com/tag/culture/page/14/
# log https://www.matataiwan.com/tag/culture/page/15/
# log https://www.matataiwan.com/tag/culture/page/16/
# ...

# %%
pact = []
count = 1
for i in links_list:
#     print('new_page_start')
    for index in range(len(i)):
#         print(count)
        count += 1
        obj = {}
        title = grab(i[index], 'h2', 'entry-title grid-title')
        link = title[0].a.get('href')
        author = grab(i[index], 'a', 'url fn n')
        date = grab(i[index], 'time', 'entry-date published')
#         print('title: ', title[0].text)
#         print('author: ', author[0].text)
#         print('link: ', link)
#         if (date):
#             print('date:', date[0].text)
#         else:
#             print('date not found')
#         print('\n')
        obj['title'] = title[0].text
        obj['link'] = link
        obj['author'] = author[0].text
        if (date):
            obj['date'] = date[0].text
        else:
            obj['date'] = 'none'
        pact.append(obj)
    
print('done')
# Out:
# done

# %%
import pandas as pd

df = pd.DataFrame(pact)
print(df)
# Out:
#           author        date  \
# 0      Mata 精選書摘  2019/04/19
# 1      Mata 精選書摘  2019/04/18
# 2      Mata 精選書摘  2018/02/02
# 3      Mata 精選書摘  2017/07/10
# 4      Mata 精選書摘  2017/07/04
# 5      Mata 精選書摘  2017/06/09
# 6      Mata 精選書摘  2017/05/09
# 7    Vanessa Lai  2016/03/29
# 8           李 建霖  2018/08/07
# 9           讀者投書  2018/05/06
# 10     Aitu Awan  2018/04/26
# 11          讀者投書  2018/03/19
# 12          讀者投書  2018/03/19
# 13     Evoked 承誌  2018/02/03
# 14     Mata 精選書摘  2018/02/02
# 15          讀者投書  2018/01/30
# 16     Evoked 承誌  2018/01/28
# 17   Vanessa Lai  2017/12/28
# 18   Vanessa Lai  2017/12/23
# 19   Vanessa Lai  2017/12/16
# 20         部落好朋友  2017/12/14
# 21   Vanessa Lai  2017/12/07
# 22         部落好朋友  2017/11/29
# 23          讀者投書  2017/11/28
# 24     Mata 精選書摘  2017/11/27
# 25            寒波  2017/11/20
# 26          讀者投書  2017/11/17
# 27          讀者投書  2017/11/16
# 28   Vanessa Lai  2017/11/03
# 29          讀者投書  2017/10/13
# ..           ...         ...
# ...
